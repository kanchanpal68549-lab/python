# %%
import pandas as pd
import numpy as np

# %%
data = {"eid":[101,102,103,104,105, 106, 107, 108, 109, 110],"ename":["Kiran","Khushbu","Suraj","Pradeep"],
        "basic":[23000,34000,45000,45000]}
df = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 data = {"eid":[101,102,103,104,105, 106, 107, 108, 109, 110],"ename":["Kiran","Khushbu","Suraj","Pradeep"],
#       2         "basic":[23000,34000,45000,45000]}
# ----> 3 df = pd.DataFrame(data)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:782, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     776     mgr = self._init_mgr(
#     777         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     778     )
#     780 elif isinstance(data, dict):
#     781     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 782     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     783 elif isinstance(data, ma.MaskedArray):
#     784     from numpy.ma import mrecords
#
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df[df["basic"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df[df["basic"]]
#
# NameError: name 'df' is not defined

# %%
df[(df["basic"]>= 50000  |(df["location"]=="Pune")]  # for or we use &
# Out:
#   Cell In[5], line 1
#     df[(df["basic"]>= 50000 & (df["location"]=="Pune")]
#                                                       ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('

# %%
df[(df["basic"]>= 50000]) | (df["location"]=="Pune")]     # for or we use |
# Out:
#   Cell In[6], line 1
#     df[(df["basic"]>= 50000 & (df["location"]=="Pune")]     # for or we use |
#                                                       ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('

# %%
df[df]

# %%
df.sort_values("Basic")

# %%
df.sort_values("ename")

# %%
df.sort_values("location")

# %%
df.sort_values(["location","ename"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.sort_values(["location","ename"])
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Merging
