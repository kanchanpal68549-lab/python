# %%
## emp

# %%
class Emp:
    def __init__(self, eid, ename, basic):
        self.eid = eid
        self.ename = ename
        self.basic = basic

    def display(self):
        print("Eid =", self.eid)
        print("EName =", self.ename)
        print("Basic =", self.basic)


# Create object
e1 = Emp(101, "Rupesh", 32000)

# Call method
e1.display()
# Out:
# Eid = 101
# EName = Rupesh
# Basic = 32000

# %%
## company

# %%
class Emp:
    def __init__(self, eid, ename, basic):
        self.eid = eid
        self.ename = ename
        self.basic = basic

    def display(self):
        print("Eid =", self.eid)
        print("EName =", self.ename)
        print("Basic =", self.basic)


class Company:
    def __init__(self):
        self.allEmps = {}

    def addEmp(self, e):
        if e.eid in self.allEmps:
            print("This employee already exists")
        else:
            self.allEmps[e.eid] = e

    def display(self):
        for emp in self.allEmps.values():
            emp.display()
            print("----------------------------")

# %%
## main

# %%
data = {
    101: "Priyanka",
    102: "Ritu",
    103: "Zunaid",
    104: "Shruti"
}

choice = 0

while choice != 6:
    print("\n\t\t1. Add new item")
    print("\t\t2. Search an item")
    print("\t\t3. Delete an item")
    print("\t\t4. Display all items")
    print("\t\t5. Edit an item")
    print("\t\t6. Exit")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        key = int(input("Enter the key: "))
        if key in data:
            print("Duplicate key! Already exists.")
        else:
            value = input("Enter the value: ")
            data[key] = value
            print("Item added successfully.")

    elif choice == 2:
        key = int(input("Enter the key: "))
        if key in data:
            print(key, "is present and its value is", data[key])
        else:
            print("Key not found.")

    elif choice == 3:
        key = int(input("Enter the key you want to delete: "))
        if key in data:
            data.pop(key)
            print("Item deleted successfully.")
        else:
            print(key, "is not present.")

    elif choice == 4:
        print("\nDictionary Contents:")
        for key, value in data.items():
            print(key, ":", value)

    elif choice == 5:
        key = int(input("Enter the key you want to edit: "))
        if key in data:
            value = input("Enter new value: ")
            data[key] = value
            print("Item updated successfully.")
        else:
            print(key, "is not present.")

    elif choice == 6:
        print("------------- End of Program -------------")

    else:
        print("Invalid Choice! Please enter a number between 1 and 6.")
# Out:
# 		1. Add new item
# 		2. Search an item
# 		3. Delete an item
# 		4. Display all items
# 		5. Edit an item
# 		6. Exit
# Enter your choice:  6
# ------------- End of Program -------------

# %%
## menu

# %%
data = {101:"Priyanka",102:"Ritu",103:"Zunaid",104:"Shruti"}

choice = 0

while choice != 6:
    print("\t\t1. Add new item")
    print("\t\t2. Search an item")
    print("\t\t3. Delete an item")
    print("\t\t4. Display all items")
    print("\t\t5. Edit an item")
    print("\t\t6. Exit")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        key = int(input("Enter the key: "))
        if key in data:
            print("It's a duplicate")
        else:
            value = input("Enter the value: ")
            data[key] = value

    elif choice == 2:
        key = int(input("Enter the key: "))
        if key in data:
            print(key, "is present and its value is", data[key])
        else:
            print("It is not present")

    elif choice == 3:
        key = int(input("Enter the key you want to delete: "))
        if key in data:
            data.pop(key)
            print("Item deleted successfully")
        else:
            print(key, "is not present")

    elif choice == 4:
        print(data)

    elif choice == 5:
        key = int(input("Enter the key you want to edit: "))
        if key in data:
            value = input("Enter new value: ")
            data[key] = value
            print("Item updated successfully")
        else:
            print(key, "is not present")

    elif choice == 6:
        print("------------- End of program ---------------")

    else:
        print("Invalid choice")
# Out:
# 		1. Add new item
# 		2. Search an item
# 		3. Delete an item
# 		4. Display all items
# 		5. Edit an item
# 		6. Exit
# Enter your choice:  6
# ------------- End of program ---------------

# %%
## dictdemo1

# %%
data = {}
print(data)
#This tells the data type 
print(type(data))
data = dict()
print(data)
#This tells the data type 
print(type(data))
# Out:
# {}
# <class 'dict'>
# {}
# <class 'dict'>

# %%
## dictdemo2

# %%
data = {101:"Priyanka",102:"Ritu",103:"Zunaid",104:"Shruti"}
print(data)
print(data.keys())
print(data.values())
print(data.items())
print("------------------------------")
#It will fetch only keys
for x in data:
    print(x)
print("------------------------------")
for x in data.keys():
    print(x)
print("------------------------------")
for x in data.values():
    print(x)
print("------------------------------")
for x in data.items():
    print(x)
print("------------------------------")
for x,y in data.items():
    print(x," = ",y)
# Out:
# {101: 'Priyanka', 102: 'Ritu', 103: 'Zunaid', 104: 'Shruti'}
# dict_keys([101, 102, 103, 104])
# dict_values(['Priyanka', 'Ritu', 'Zunaid', 'Shruti'])
# dict_items([(101, 'Priyanka'), (102, 'Ritu'), (103, 'Zunaid'), (104, 'Shruti')])
# ------------------------------
# 101
# 102
# 103
# 104
# ------------------------------
# 101
# 102
# 103
# 104
# ------------------------------
# Priyanka
# Ritu
# Zunaid
# Shruti
# ------------------------------
# (101, 'Priyanka')
# (102, 'Ritu')
# (103, 'Zunaid')
# (104, 'Shruti')
# ------------------------------
# 101  =  Priyanka
# 102  =  Ritu
# 103  =  Zunaid
# 104  =  Shruti

# %%
## dict_remove

# %%
data = {101:"Priyanka",102:"Ritu",103:"Zunaid",104:"Shruti"}
print("Before removing : ",data)
#It removes the last item
item = data.popitem()
print(item)
print("After removing :",data)
#If key is not present it will raise error
item = data.pop(101)
print(item)
print("After removing :",data)
#If key is not present it will raise error
del data[106] #Remove using key
print(data)
data.clear()#Removes all items
del data #Remove items as well as dictionary object
# Out:
# Before removing :  {101: 'Priyanka', 102: 'Ritu', 103: 'Zunaid', 104: 'Shruti'}
# (104, 'Shruti')
# After removing : {101: 'Priyanka', 102: 'Ritu', 103: 'Zunaid'}
# Priyanka
# After removing : {102: 'Ritu', 103: 'Zunaid'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 12
#      10 print("After removing :",data)
#      11 #If key is not present it will raise error
# ---> 12 del data[106] #Remove using key
#      13 print(data)
#      14 data.clear()#Removes all items
#
# KeyError: 106

# %%
## dict_oprations

# %%
data = [10,20,30,40,45]
# in -> membership operator
if 30 in data:
    print(30, " is present")
else:
    print(30," is not present")

data = {101:"Priyanka",102:"Ritu",103:"Zunaid",104:"Shruti"}
if 103 in data:
    print(103," is present")
#It will return the value of that key
#If key does not exist then error is returned
x = data[101]
print(x)
#If key does not exist, it will return None, instead of error
value = data.get(111)
print(value)
#We can specify customized output if value not found
value = data.get(111,"Not found")
print(value)
print(len(data))
print(max(data))
print(min(data))
# Out:
# 30  is present
# 103  is present
# Priyanka
# None
# Not found
# 4
# 104
# 101

# %%
## dict_add

# %%
data = {101:"Priyanka",102:"Ritu",103:"Zunaid",104:"Shruti"}
#To add new item
data[105] = "Kiran"
print(data)
#To modify the item
data[101] = "Seema"
print(data)
mydict = {1:"A",2:"B",3:"C"}
#Update is used to add new dict into existing dict
data.update(mydict)
print(data)
