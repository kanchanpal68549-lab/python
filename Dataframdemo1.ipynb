# %%
import pandas as pd
import numpy as np

# %%
#Empty
df = pd.DataFrame()

# %%
arr = np.arange(1,21).reshape(4,5)
df = pd.DataFrame(arr)

# %%
data = {"roll_no":[101,102,103,104,105],"name":["Ajay","Sanjay","Nisha","Nidhi","Suraj"],"percentage":[78,89,56,71,77]}
df = pd.DataFrame(data)

# %%
df
# Out:
#    roll_no    name  percentage
# 0      101    Ajay          78
# 1      102  Sanjay          89
# 2      103   Nisha          56
# 3      104   Nidhi          71
# 4      105   Suraj          77

# %%
df.roll_no #columns
# Out:
# 0    101
# 1    102
# 2    103
# 3    104
# 4    105
# Name: roll_no, dtype: int64

# %%
df['roll_no']  #columns
# Out:
# 0    101
# 1    102
# 2    103
# 3    104
# 4    105
# Name: roll_no, dtype: int64

# %%
df[['roll_no','name']]   #columns
# Out:
#    roll_no    name
# 0      101    Ajay
# 1      102  Sanjay
# 2      103   Nisha
# 3      104   Nidhi
# 4      105   Suraj

# %%
df.iloc[0] # row
# Out:
# roll_no        101
# name          Ajay
# percentage      78
# Name: 0, dtype: object

# %%
df.loc['a'] # row
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df.loc['a'] # row
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1432, in _LocIndexer._getitem_axis(self, key, axis)
#    1430 # fall thru to straight lookup
#    1431 self._validate_key(key, axis)
# -> 1432 return self._get_label(key, axis=axis)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1382, in _LocIndexer._get_label(self, label, axis)
#    1380 def _get_label(self, label, axis: AxisInt):
# ...

# %%
df.iloc[[0,2,3]] # row
# Out:
#    roll_no   name  percentage
# 0      101   Ajay          78
# 2      103  Nisha          56
# 3      104  Nidhi          71

# %%
# Adding a new columns

# %%
data = {"location":["Pune","Mumbai","Nagpur"]}
df_location = pd.DataFrame(data)

# %%
import pandas as pd

# %%
data ={"Name":["John","Peter","Lisa"],
    "Age":[25,28,31],
       "Salary":[30000,45000,25000]
}


df = pd.DataFrame(data)

print(df)
# Out:
#     Name  Age  Salary
# 0   John   25   30000
# 1  Peter   28   45000
# 2   Lisa   31   25000

# %%
df.iloc[0] # row
# Out:
# Name       John
# Age          25
# Salary    30000
# Name: 0, dtype: object
