# %%
name = "bill"
age = 20
marks = 55
print("your name is" , name, "and your age is", age, "marks is", marks)
# Out:
# your name is bill and your age is 20 marks is 55

# %%
a = b = c= 5
print(a)
print(b)
print(c)
# Out:
# 5
# 5
# 5

# %%
a = b = c= 5, 'xyz', 45.5
print(a)
#print(b)
#print(c)
# Out:
# (5, 'xyz', 45.5)

# %%
#rollno = 4
roll_no43 = 45
#roll$no = 45
print(roll_no43)
# Out:
# 45

# %%
a = 5
print(id(a))

a = 10
print(id(a))

c = 10
print(id(a))
# Out:
# 140718928374328
# 140718928374488
# 140718928374488

# %%
name = "bill"
age = 20
marks = 55
marks = 78
print("your name is" , name, "and your age is", age, "marks is", marks)
# Out:
# your name is bill and your age is 20 marks is 78

# %%
21321432 = "ffsd"
# Out:
#   Cell In[25], line 1
#     21321432 = "ffsd"
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
a = 34
A = 46
print(a)
print(A)
# Out:
# 34
# 46

# %%
x = 12
x >>= 2
print(x)

# %%
x = 16
x >>= 3
print(x)

# %%
x = 16
x <<= 3
print(x)
# Out:
# 128

# %%
x = 12
x <<= 2
print(x)
# Out:
# 48

# %%
print(x := 5)
# Out:
# 5
