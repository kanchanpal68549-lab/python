# %%
id = 5
print(type(id))
# Out:
# <class 'int'>

# %%
name = 'steve'
print(type(name))
# Out:
# <class 'str'>

# %%
id = -56756.786476567434867978959
print(type(id))
# Out:
# <class 'float'>

# %%
i = 4+7j
print(type(i))
# Out:
# <class 'complex'>

# %%
i = complex(5,6)
print(i)
print(type(i))
# Out:
# (5+6j)
# <class 'complex'>

# %%
i = False
print(type(i))
# Out:
# <class 'bool'>

# %%
a = None
print(type(a))
# Out:
# <class 'NoneType'>

# %%
list = [1,2,'steve',False]
print(type(list))
# Out:
# <class 'list'>

# %%
tup = (1,2,'steve',False,5346,678,)
print(type(tup))
# Out:
# <class 'tuple'>

# %%
my_set = (1,2,4,6,8,6,7)
print(my_set)
print(type(my_set))
# Out:
# (1, 2, 4, 6, 8, 6, 7)
# <class 'tuple'>

# %%
employees = ("name","steve","company","Apple" ,"id",5)
print(employees)
print(type(employees))
# Out:
# ('name', 'steve', 'company', 'Apple', 'id', 5)
# <class 'tuple'>

# %%
#typecosting

# %%
a = 54
a = "abc"
print(a)
print(type(a))
# Out:
# abc
# <class 'str'>

# %%
a =5
b =7
print(a+b)
# Out:
# 12

# %%
a = 'kanc'
b = 'han'
print(a+b)
# Out:
# kanchan

# %%
a = '54'
b = 6
print(type(a))
print(type(b))

print(a+b)
# Out:
# <class 'str'>
# <class 'int'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 5
#       3 print(type(a))
#       4 print(type(b))
# ----> 5 print(a+b)
#
# TypeError: can only concatenate str (not "int") to str

# %%
a = 54
b = 6
print(type(a))
print(type(b))
print(a+b)
# Out:
# <class 'int'>
# <class 'int'>
# 60

# %%
a = input('enter the first num')
b = input('enter the second num')
print(int(a)+int(b))
# Out:
# enter the first num 54
# enter the second num 56
# 110

# %% [markdown]
# # demo exercise

# %%
age = int(input("enter your age in years ="))

average_age = 100

years_left = average_age - age

days_left = years_left * 52 * 7

print("you have" , str(days_left) ,"days remaining on earth.")
# Out:
# enter your age in years = 10
# you have 32760 days remaining on earth.

# %%
age = int(input("enter your age in years ="))

average_age = 100

years_left = average_age - age

days_left = years_left * 52 * 7

print("you have" + str(days_left) +"days remaining on earth.")
# Out:
# enter your age in years = 10
# you have32760days remaining on earth.

# %%
name = "logical python"

name_length= len(name)
print(type(name_length))

print('your name has' + str(name_length) +'characters')
# Out:
# <class 'int'>
# your name has14characters

# %%
a=3
b=2.6

sum= a+b

print(sum)
# Out:
# 5.6

# %%
a = 5
b = 15

temp = a
a = b
b = temp

print(a)
print(b)
# Out:
# 15
# 5

# %%
x= 5
y =10
x,y =y,x
print(x)
print(y)
# Out:
# 10
# 5

# %%
#IDENTI OPERATOR
