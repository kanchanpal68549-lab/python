# %%
print("hello")

# %%
print(4)

# %%
x = 3
print(x)

# %%
a = 4
print("my world",34,"xyz",a) #multivalues

# %%
print('Hello')

# %%
import sys
print(sys.version) # find the system version

# %%
#print("sam,s") # this conditions true
print("sam',"s') #this is wrong

# %%
import platform
print(platform.python_version())

# %%
import keyword
print(keyword.kwlist)

# %%
or = 2  # you cann't use any keyword in variables

# %%
help("")

# %%
print("sam's")

# %%
 # print concatenattion:
 print("abc"+"pqr") #without space
print("abc","pqr") # spacefull
# Out:
# abcpqr
# abc pqr

# %%
print(2+5)

# %%
day = 2
month = ""

# %%
tuple = (43,54,64,)
tuple = [43,54,64,["kannu",  "i am coder" ]]
print(tuple)  #() is tuple and [] is list for types
print(type(tuple))

# %%
day = 8
month = "august"
year = 2025
print(day,month,year, sep= "/")
print(day ,month, year)
print(day ,month, year, sep="-")

# %%
print("Hello",end ="|")      #without | ki value sequence nhi hogyi
print("world",end ="|")
print("wxy",end="|")
print(545)         # change the row
print(12)

# %%
print(""" Hello,
        how are you?
thanks""")

print(   """ Hello, 13,@
how are you?               
thanks"")
# Out:
#   Cell In[3], line 5
#     print(   """ Hello, 13,@
#              ^
# SyntaxError: incomplete input

# %%
with open(" pythan introduction.txt","w") as file:
    print("python",file = file)
