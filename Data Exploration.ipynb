# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('cars93.csv')

# %%
df
# Out:
#    Manufacturer    Model     Type    Price  MPG.city             AirBags  \
# 0         Acura  Integra    Small  3259500        25         Driver only
# 1         Acura   Legend  Midsize  6949500        18  Driver & Passenger
# 2          Audi       90  Compact  5965500        20         Driver only
# 3          Audi      100  Midsize  7728500        19  Driver & Passenger
# 4           BMW     535i  Midsize  6150000        22         Driver only
# ..          ...      ...      ...      ...       ...                 ...
# 88   Volkswagen  Eurovan      Van  4038500        17  Driver & Passenger
# 89   Volkswagen   Passat  Compact  4100000        21  Driver & Passenger
# 90   Volkswagen  Corrado   Sporty  4776500        18  Driver & Passenger
# 91        Volvo      240  Compact  4653500        21         Driver only
# 92        Volvo      850  Midsize  5473500        20  Driver & Passenger
#
#     Horsepower  Passengers  Rear.seat.room  Luggage.room
# ...

# %%
df.head()
# Out:
#   Manufacturer    Model     Type    Price  MPG.city             AirBags  \
# 0        Acura  Integra    Small  3259500        25         Driver only
# 1        Acura   Legend  Midsize  6949500        18  Driver & Passenger
# 2         Audi       90  Compact  5965500        20         Driver only
# 3         Audi      100  Midsize  7728500        19  Driver & Passenger
# 4          BMW     535i  Midsize  6150000        22         Driver only
#
#    Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0         140           5            26.5          11.0
# 1         200           5            30.0          15.0
# 2         172           5            28.0          14.0
# 3         172           6            31.0          17.0
# 4         208           4            27.0          13.0

# %%
print("Rows : ",df.shape[0])
print("Columns : ",df.shape[1])
# Out:
# Rows :  93
# Columns :  10

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model', 'Type', 'Price', 'MPG.city', 'AirBags',
#        'Horsepower', 'Passengers', 'Rear.seat.room', 'Luggage.room'],
#       dtype='object')

# %%
df.describe()
# Out:
#               Price   MPG.city  Horsepower  Passengers  Rear.seat.room  \
# count  9.300000e+01  93.000000   93.000000   93.000000       91.000000
# mean   3.999484e+06  22.365591  143.827957    5.086022       27.829670
# std    1.980183e+06   5.619812   52.374410    1.038979        2.989072
# min    1.517000e+06  15.000000   55.000000    2.000000       19.000000
# 25%    2.501000e+06  18.000000  103.000000    4.000000       26.000000
# 50%    3.628500e+06  21.000000  140.000000    5.000000       27.500000
# 75%    4.776500e+06  25.000000  170.000000    6.000000       30.000000
# max    1.268950e+07  46.000000  300.000000    8.000000       36.000000
#
#        Luggage.room
# count     82.000000
# mean      13.890244
# std        2.997967
# min        6.000000
# 25%       12.000000
# 50%       14.000000
# 75%       15.000000
# max       22.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Manufacturer    93 non-null     object
#  1   Model           93 non-null     object
#  2   Type            93 non-null     object
#  3   Price           93 non-null     int64
#  4   MPG.city        93 non-null     int64
#  5   AirBags         79 non-null     object
#  6   Horsepower      93 non-null     int64
#  7   Passengers      93 non-null     int64
#  8   Rear.seat.room  91 non-null     float64
#  9   Luggage.room    82 non-null     float64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 7.4+ KB

# %%
df.isna().sum()
# Out:
# Manufacturer       0
# Model              0
# Type               0
# Price              0
# MPG.city           0
# AirBags           14
# Horsepower         0
# Passengers         0
# Rear.seat.room     2
# Luggage.room      11
# dtype: int64

# %%
df['Rear.seat.room'].mean()
# Out:
# np.float64(27.82967032967033)

# %%
x = df['Rear.seat.room'].median()

# %%
df['Rear.seat.room'] = df['Rear.seat.room'].fillna(value=x)

# %%
df.isna().sum()
# Out:
# Manufacturer       0
# Model              0
# Type               0
# Price              0
# MPG.city           0
# AirBags           14
# Horsepower         0
# Passengers         0
# Rear.seat.room     0
# Luggage.room      11
# dtype: int64

# %%
df['Luggage.room'].mean()
# Out:
# np.float64(13.890243902439025)

# %%
df['Luggage.room'].median()
# Out:
# 14.0

# %%
x = df['Luggage.room'].median()

# %%
df['Luggage.room'] = df['Luggage.room'].fillna(value=x)

# %%
df.isna().sum()
# Out:
# Manufacturer       0
# Model              0
# Type               0
# Price              0
# MPG.city           0
# AirBags           14
# Horsepower         0
# Passengers         0
# Rear.seat.room     0
# Luggage.room       0
# dtype: int64

# %%
df['AirBags'].mode()
# Out:
# 0    Driver only
# Name: AirBags, dtype: object

# %%
x = df['AirBags'].mode()[0]

# %%
df['AirBags'] = df['AirBags'].fillna(value=x)

# %%
df.head()
# Out:
#   Manufacturer    Model     Type    Price  MPG.city             AirBags  \
# 0        Acura  Integra    Small  3259500        25         Driver only
# 1        Acura   Legend  Midsize  6949500        18  Driver & Passenger
# 2         Audi       90  Compact  5965500        20         Driver only
# 3         Audi      100  Midsize  7728500        19  Driver & Passenger
# 4          BMW     535i  Midsize  6150000        22         Driver only
#
#    Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0         140           5            26.5          11.0
# 1         200           5            30.0          15.0
# 2         172           5            28.0          14.0
# 3         172           6            31.0          17.0
# 4         208           4            27.0          13.0

# %%
#Normalization
from sklearn.preprocessing import MinMaxScaler

# %%
min_max = MinMaxScaler()

# %%
df.Price.min()
# Out:
# 1517000

# %%
df['Price'].max()
# Out:
# 12689500

# %% [markdown]
# ## Add the new normalized column into our existing dataframe

# %%
price_normalized = (
    (df['Price'] - df['Price'].min()) /
    (df['Price'].max() - df['Price'].min())
)

df['price_normalized'] = price_normalized

# %%
df[['Price', 'price_normalized']].head()
# Out:
#      Price  price_normalized
# 0  3259500          0.155963
# 1  6949500          0.486239
# 2  5965500          0.398165
# 3  7728500          0.555963
# 4  6150000          0.414679

# %% [markdown]
# ## Performing Standardization on Horse Power

# %%
from sklearn.preprocessing import StandardScaler

std_scaler = StandardScaler()

df['Price_standardized'] = std_scaler.fit_transform(df[['Price']])

# %%
hoursepower_std = std_scaler.fit_transform(df[['Horsepower']])

# %%
hoursepower_std.min()
# Out:
# np.float64(-1.705210877485415)

# %%
hoursepower_std.max()
# Out:
# np.float64(2.998000579179055)

# %%
df['Horsepower_Std'] = hoursepower_std

# %% [markdown]
# ## Data Encoding - One-Hot Encoding

# %%
df_encoded = pd.get_dummies(df)

# %%
df_encoded.shape
# Out:
# (93, 143)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Manufacturer        93 non-null     object
#  1   Model               93 non-null     object
#  2   Type                93 non-null     object
#  3   Price               93 non-null     int64
#  4   MPG.city            93 non-null     int64
#  5   AirBags             93 non-null     object
#  6   Horsepower          93 non-null     int64
#  7   Passengers          93 non-null     int64
#  8   Rear.seat.room      93 non-null     float64
#  9   Luggage.room        93 non-null     float64
#  10  type_encoded        93 non-null     int64
#  11  price_normalized    93 non-null     float64
#  12  Price_standardized  93 non-null     float64
#  13  Horsepower_Std      93 non-null     float64
# dtypes: float64(5), int64(5), object(4)
# memory usage: 10.3+ KB

# %%
len(df['Manufacturer'].unique())
# Out:
# 32

# %%
len(df['Model'].unique())
# Out:
# 93

# %%
len(df['Type'].unique())
# Out:
# 6

# %%
len(df['AirBags'].unique())
# Out:
# 2

# %%
2+6+93+32-4
# Out:
# 129

# %%
129+12
# Out:
# 141

# %%
df.shape[1]
# Out:
# 14

# %%
12+133
# Out:
# 145

# %%
df_encoded.shape
# Out:
# (93, 143)

# %%
df_encoded.columns
# Out:
# Index(['Price', 'MPG.city', 'Horsepower', 'Passengers', 'Rear.seat.room',
#        'Luggage.room', 'type_encoded', 'price_normalized',
#        'Price_standardized', 'Horsepower_Std',
#        ...
#        'Model_Town_Car', 'Model_Vision', 'Type_Compact', 'Type_Large',
#        'Type_Midsize', 'Type_Small', 'Type_Sporty', 'Type_Van',
#        'AirBags_Driver & Passenger', 'AirBags_Driver only'],
#       dtype='object', length=143)

# %%
df.AirBags.unique()
# Out:
# array(['Driver only', 'Driver & Passenger'], dtype=object)

# %%
df.Type.unique()
# Out:
# array(['Small', 'Midsize', 'Compact', 'Large', 'Sporty', 'Van'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

# %%
df_encoded = label_encoder.fit_transform(df["Type"])

# %%
df_encoded
# Out:
# array([3, 2, 0, 2, 2, 2, 1, 1, 2, 1, 2, 0, 0, 4, 2, 5, 5, 1, 4, 1, 0, 1,
#        3, 3, 0, 5, 2, 4, 3, 1, 3, 3, 0, 4, 4, 5, 2, 1, 3, 4, 4, 3, 0, 3,
#        3, 4, 2, 2, 2, 2, 2, 1, 3, 3, 0, 5, 4, 0, 2, 4, 2, 3, 2, 3, 0, 5,
#        2, 0, 2, 5, 1, 4, 3, 0, 4, 2, 1, 0, 3, 3, 3, 0, 3, 3, 4, 2, 5, 3,
#        5, 0, 4, 0, 2])

# %%
df['type_encoded'] = df_encoded

# %%
 df_encoded
# Out:
# array([3, 2, 0, 2, 2, 2, 1, 1, 2, 1, 2, 0, 0, 4, 2, 5, 5, 1, 4, 1, 0, 1,
#        3, 3, 0, 5, 2, 4, 3, 1, 3, 3, 0, 4, 4, 5, 2, 1, 3, 4, 4, 3, 0, 3,
#        3, 4, 2, 2, 2, 2, 2, 1, 3, 3, 0, 5, 4, 0, 2, 4, 2, 3, 2, 3, 0, 5,
#        2, 0, 2, 5, 1, 4, 3, 0, 4, 2, 1, 0, 3, 3, 3, 0, 3, 3, 4, 2, 5, 3,
#        5, 0, 4, 0, 2])
