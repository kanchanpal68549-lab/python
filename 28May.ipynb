# %% [markdown]
#  # ListDemo

# %%
data = []
print()

data = list()
print()

data = [1,2,3,4]
print(data)
data = list([1,2,3,4])
print(data)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %% [markdown]
# ## List_search

# %%
data = [1,2,3,4,5]
#If we specify element which is not present then error is raised
index = data.index(30)
print(index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 data = [1,2,3,4,5]
#       2 #If we specify element which is not present then error is raised
# ----> 3 index = data.index(30)
#       4 print(index)
#
# ValueError: 30 is not in list

# %% [markdown]
# ## List_removeElement

# %%
data = [1,2,3,4,5]
x = data.pop()
print(data)
print(x,"  was removed")
data.remove(2) #Removes element which is specified
print(data)
#If element is not present then error is raised
# data.remove(20) #Removes element which is specified
# print(data)
#removes element with specified index
del data[0]
print(data)
data.clear()
print(data)
# Out:
# [1, 2, 3, 4]
# 5   was removed
# [1, 3, 4]
# [3, 4]
# []

# %% [markdown]
# ## List_operations

# %%
data = [1,2,4,1,33,2,1,4,55,46,1,2,4,55,7,8,10]
#How many elements are there in list
print(len(data))
#Calculate sum of all elements
print(sum(data))
#Find maximum element
print(max(data))
#Find minimum element
print(min(data))
data.sort()
print(data)
data.sort(reverse=True)
print(data)
data.reverse()
print(data)
print(data.count(1)) #It will tell how many times 1 is present in list
# Out:
# 17
# 236
# 55
# 1
# [1, 1, 1, 1, 2, 2, 2, 4, 4, 4, 7, 8, 10, 33, 46, 55, 55]
# [55, 55, 46, 33, 10, 8, 7, 4, 4, 4, 2, 2, 2, 1, 1, 1, 1]
# [1, 1, 1, 1, 2, 2, 2, 4, 4, 4, 7, 8, 10, 33, 46, 55, 55]
# 4

# %% [markdown]
# ## List_modify

# %%
data = [1,2,3,4,5]
#Modify the element using index
data[0] = 44
print(data)
# Out:
# [44, 2, 3, 4, 5]

# %% [markdown]
# ## List_display

# %%
data = [1,2,3,4,5]
print(data)
print(data[3])
print(data[-1])
for x in data:
    print(x)
# Out:
# [1, 2, 3, 4, 5]
# 4
# 5
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## List_addelement

# %%
data = [1,2,3,4,5]
data.append(55)
print(data)
data.insert(1,90)
print(data)
#If index is invalid, it adds element towards the end of list
data.insert(100,90)
print(data)
extra = [11,22,33]
data.extend(extra)
print(data)
# Out:
# [1, 2, 3, 4, 5, 55]
# [1, 90, 2, 3, 4, 5, 55]
# [1, 90, 2, 3, 4, 5, 55, 90]
# [1, 90, 2, 3, 4, 5, 55, 90, 11, 22, 33]

# %% [markdown]
# ## main_list

# %%
data = [1,2,3,4]
choice = 0
while choice !=6:
    print("\t\t1.Add Element")
    print("\t\t2. Remove element")
    print("\t\t3. Modify element")
    print("\t\t4. Search element")
    print("\t\t5. Display all elements")
    print("\t\t6. Exit")
    choice = int(input("Enter your choice : "))
    if choice == 1:
        x = int(input("Enter an element : "))
        data.append(x)
    elif choice == 2:
        x = int(input("Which element you want to remove : "))
        data.remove (x)
    elif choice == 3:
        x = int(input("Which element you want to modify : "))
        index = data.index(x)
        data[index] = int(input("Enter new element : "))
    elif choice == 4:
        x = int(input("Which element you want to search : "))
        index = data.index(x)
        print(x," is present at index ",index)
    elif choice == 5:
        print(data)
    elif choice == 6:
        print("----------------End of Program--------------------")
# Out:
# 		1.Add Element
# 		2. Remove element
# 		3. Modify element
# 		4. Search element
# 		5. Display all elements
# 		6. Exit
# Enter your choice :  6
# ----------------End of Program--------------------

# %% [markdown]
# # CountDemo

# %%
data = [1,2,4,1,33,2,1,4,55,46,1,2,4,55,7,8,10]
#Get unique elements from list
elements = set(data)
for x in elements:
    print(x," is present ",data.count(x)," times ")
# Out:
# 1  is present  4  times
# 2  is present  3  times
# 33  is present  1  times
# 4  is present  3  times
# 7  is present  1  times
# 8  is present  1  times
# 10  is present  1  times
# 46  is present  1  times
# 55  is present  2  times

# %% [markdown]
# # TupleDemo

# %%
data = (1,2,3,4)
for x in data:
    print(x)

print(len(data))

#Calculate sum of all elements
print(sum(data))

#Find maximum element
print(max(data))

#Find minimum element
print(min(data))

print(data.count(1)) #It will tell how many times 1 is present in list
# Out:
# 1
# 2
# 3
# 4
# 4
# 10
# 4
# 1
# 1
