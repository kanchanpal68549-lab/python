# %% [markdown]
# # List

# %%
name = ["kannu", "kanchan", "Ragini"]
print(name)

# %%
## duplcate value

# %%
thislist = ["apple","banana","cherry","apple","cherry"]
print(type(thislist))
# Out:
# <class 'list'>

# %%
## Lenght

# %%
thislist = ["apple","banana","cherry","apple","cherry"]
print(len(thislist))

# %%
list1 = ["apple","banana","cherry"]
list2 = (1, 2, 3, 4, 5, 6, 7, 8)
list3 = {True, False, False}

print(type(list1))
print(type(list2))
print(type(list3))

# %% [markdown]
# # The list() constructor

# %%
thislist = list[{(("apple","banana","cherry"))}]
print(thislist)

# %%
thislist = ["apple","banana","cherry"]
print(thislist[1])

# %%
thislist = ["apple","banana","cherry"]
print(thislist[-1])

# %%
thislist = ["apple", "banana", "cherray", "orange", "kiwi", "melon", "mango"]
print(thislist[2:5])

# %%
thislist = ["apple", "banana", "cherray", "orange", "kiwi", "melon", "mango"]
print(thislist[2:-5])

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[:4])

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[4:])

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[2:])

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[-4:-1])

# %%
thislist = ["apple", "banana", "cherry"]
if "apple" in thislist:
  print("Yes, 'apple' is in the fruits list")

# %%
thislist = ["apple", "banana", "cherry"]
if "kannu" in thislist:
  print("No, 'apple' is in the fruits list")

# %%
thislist = ["apple", "banana", "cherry"]
thislist.append(2)
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 2]

# %% [markdown]
# # changge item value

# %%
thislist = ["apple", "banana", "cherry"]
thislist[1] = "blackcurrant"
print(thislist)

# %% [markdown]
# **change range item value**

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
thislist[1:3] = ["blackcurrant", "watermelon"]
print(thislist)

# %%
thislist = ["apple", "banana", "cherry"]

thislist[1:2] = ["blackcurrant", "watermelon"]

print(thislist)

# %% [markdown]
# **Appand item list**

# %%
thislist = ["apple", "banana", "cherry"]
thislist.append("orange")
print(thislist)

# %%
thislist = ["apple", "banana", "cherry"]
thislist.insert(1, "orange")
print(thislist)

# %%
thislist = ["apple", "banana", "cherry"]
tropical = ["mango", "pineapple", "papaya"]
thislist.extend(tropical)
print(thislist)

# %% [markdown]
# # Remove Specified Item

# %%
thislist = ["apple", "banana", "cherry"]
thislist.remove("banana")
print(thislist)

# %%
thislist = ["apple", "banana", "cherry", "banana", "kiwi"]
thislist.remove("banana")
print(thislist)

# %%
thislist = ["apple", "banana", "cherry"]
thislist.pop(1)
print(thislist)

# %%
## Clear the List

# %%
thislist = ["apple", "banana", "cherry"]
thislist.clear()
print(thislist)

# %% [markdown]
# ## List varieties

# %%
a = [1,3,5,7,9]
b = [2,4,6,8,10]
c = [a,b]
print(c[0][0]) #c[1][2]
print(c[1])

# %%
# EXERCISE

# %%
#ENTER 3 NAMES AND SAVE THEM IN A LIST

# %%
names = []
for i in range(1,4):
    name = input("enter name(i):")
    names.append(name)
    print("names",names)
# Out:
# enter name(i): riya
# names ['riya']
# enter name(i): priya
# names ['riya', 'priya']
# enter name(i): diya
# names ['riya', 'priya', 'diya']

# %%
# a list contains 10 numbers write a program to remove dup1licates from the list
numbers = [1,2,3,4,3,4,1,2]

# %%
unique = []
numbers = [1,2,3,4,3,4,1,2]

for i in numbers:
    if i not in unique:
        unique.append(i)
print(unique)
# Out:
# [1, 2, 3, 4]

# %%
numbers = [1,2,3,4,3,4,1,2]
numbers.pop(4)
print(numbers)
# Out:
# [1, 2, 3, 4, 4, 1, 2]

# %%
numbers = [1,2,3,4,3,4,1,2]
numbers.remove(3)
print(numbers)
# Out:
# [1, 2, 4, 3, 4, 1, 2]

# %%
# here is list with 5 names. the find character from the list and make a new list.
names = ['steve','parag','sandeep','rohit','atul']

# %%
names = ['steve','parag','sandeep','rohit','atul']
name_char = []
for i in names:
    print(i[0])
# Out:
# s
# p
# s
# r
# a

# %%
# enter 3 names using single input,each separated by the space. convert them into a list.

# %%
names = input("enter 3 names  separated by space")
names_list = names.split(" ")
print(names_list)
# Out:
# enter 3 names  separated by space Diya Mohit Ram
# ['Diya', 'Mohit', 'Ram']

# %%
names = input("enter 3 names separated by space: ")
names_list = names.split()   # splits on any whitespace
print(names_list)
# Out:
# enter 3 names separated by space:  Alice Bob Charlie
# ['Alice', 'Bob', 'Charlie']

# %%
names = input("enter 3 names separated by space: ")
names_list = names.split(" ", 2)   # at most 3 parts
print(names_list)
# Out:
# enter 3 names separated by space:  Naman Aman Shiyam
# ['Naman', 'Aman', 'Shiyam']

# %%
names = list(map(str, input("enter 3 names separated by space: ").split()))
print(names)
# Out:
# enter 3 names separated by space:  Naman Aman Shiyam
# ['Naman', 'Aman', 'Shiyam']

# %% [markdown]
# # DICTINARY

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 2000
}
print(thisdict)

# %% [markdown]
# # dictionary items

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 2000
}
print(len(thisdict["brand"]))
print(thisdict["model"])

# %% [markdown]
# # dictionary item datatype

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 2000,
 "colors": ["red","white","blue"]
}
print(thisdict)

# %% [markdown]
# ## dictionary constructor

# %%
thisdict = dict(name = "riya", age = 18, country = "india")
print(thisdict)

# %% [markdown]
# # access dictionary item

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 2000
}
x = thisdict["model"]
print(x)

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 2000
}
x = thisdict.keys()
print(x)

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 2000
}
x = thisdict.keys()
print(x)
thisdict["color"] = "white"
print(thisdict)

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 2000
}
x = thisdict.values()
print(x

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 2000
}
x = thisdict.items()
print(x)

# %%
car = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 2000
}
x = car.items()
print(x)
car["color"] = 'red'
print(x)

# %%
# change item

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 2000
}
thisdict["year"] = 2020
thisdict["model"] = " "
print(thisdict)

# %%
#update dictionary

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 2000
}
thisdict.update({"color": 'red'})
print(thisdict)

# %% [markdown]
# # remove items

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 2000
}
thisdict.pop("brand")
print(thisdict)

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 2000
}
thisdict.popitem()
print(thisdict)

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 2000
}
del thisdict["brand"]
print(thisdict)

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 2000
}
thisdict.clear()
print(thisdict)

# %%
emp_details = {
    "first_name": 'diya',
    "last_name": "yadav",
    "emp_id": 13,
    "bill": 50.0
}
print(emp_details["first_name"])
print(emp_details["last_name"])
print(emp_details["bill"])

# %% [markdown]
# # Loop dictionary

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 2000
}
for x in thisdict:
    print(x)

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 2000
}
for x in thisdict:
    print(thisdict[x])

# %% [markdown]
# ## copy dictionary

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 2000
}
mydict = thisdict.copy()
print(mydict)

# %% [markdown]
# # nested dictionary

# %%
myfamily = {
    "child1": {
        "name": "Raman",
        "year": 2004
    },
    "child2": {
        "name": "Riya",
        "year": 2005
    },
    "child3": {
        "name": "Nisha",
        "year": 2011
    }
}
print(myfamily)
# Out:
# {'child1': {'name': 'Raman', 'year': 2004}, 'child2': {'name': 'Riya', 'year': 2005}, 'child3': {'name': 'Nisha', 'year': 2011}}

# %%
x = ("key1","key2","key3")
y = 45
thisdict = dict.fromkeys(x,y)
print(thisdict)
# Out:
# {'key1': 45, 'key2': 45, 'key3': 45}

# %% [markdown]
# # tuple

# %%
my_tuple = (1,2,3,'Raghav',2.32)
print(my_tuple)
# Out:
# (1, 2, 3, 'Raghav', 2.32)

# %%
first_tuple = (1,2,3,4,5)
print(first_tuple)
# Out:
# (1, 2, 3, 4, 5)

# %%
my_tuple = (1,2,3,'Raghav', True,2.32)
print(my_tuple)
print(type(my_tuple))
# Out:
# (1, 2, 3, 'Raghav', True, 2.32)
# <class 'tuple'>

# %%
x = [1,2,3,'Raghav', True]
x[0] = 10
print(x)
print(type(x))
# Out:
# [10, 2, 3, 'Raghav', True]
# <class 'list'>

# %%
marks = 75,85,91,79,82
print(marks)
print(type(marks))
# Out:
# (75, 85, 91, 79, 82)
# <class 'tuple'>

# %%
marks = (75,)
print(marks)
print(type(marks))
# Out:
# (75,)
# <class 'tuple'>

# %%
marks = (75)
print(marks)
print(type(marks))
# Out:
# 75
# <class 'int'>

# %%
marks = tuple((75,85,91,79,82))
print(marks)
print(type(marks))
# Out:
# (75, 85, 91, 79, 82)
# <class 'tuple'>

# %% [markdown]
# **Immutable tuple**

# %%
x = (1,2,3,'Raghav', True)
x[0] = 10
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 2
#       1 x = (1,2,3,'Raghav', True)
# ----> 2 x[0] = 10
#       3 print(x)
#
# TypeError: 'tuple' object does not support item assignment

# %%
emp_details = ('Tim','Smith',28,True)
print(emp_details[1])
# Out:
# Smith

# %%
emp_details[1] = 'Cook'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 emp_details[1] = 'Cook'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
#  **duplicate elements tuple**

# %%
x = (1,2,3,2,3,'Raghav', True)
print(x)
# Out:
# (1, 2, 3, 2, 3, 'Raghav', True)

# %%
duplicates = ('string',1,1,1,1,1)
print(duplicates)
# Out:
# ('string', 1, 1, 1, 1, 1)

# %% [markdown]
# **Ordered tuple**

# %%
x = (1,2,3,2,3,'Raghav', True)
print(x[1])
# Out:
# 2

# %%
x = (1,2,3,2,3,'Raghav', True)
print(x[3:7])
# Out:
# (2, 3, 'Raghav', True)

# %%
my_tuple1 = (1, 2, 3)
my_tuple2 = (1, 2, 3)
print(my_tuple1 == my_tuple2)
# Out:
# True

# %%
my_tuple1 = (1, 2, 3)
my_tuple2 = (1, 3, 2)
print(my_tuple1 == my_tuple2)
# Out:
# False

# %%
x = 1,2,3,2,3,'Raghav', True
print(x)
print(type(x))
# Out:
# (1, 2, 3, 2, 3, 'Raghav', True)
# <class 'tuple'>

# %%
x = (1)
print(x)
print(type(x))
# Out:
# 1
# <class 'int'>

# %%
x = (1)
print(x)
print(type(x))
# Out:
# sgkj
# <class 'str'>

# %%
x = (1,)
print(x)
print(type(x))
# Out:
# (1,)
# <class 'tuple'>

# %%
x = ('Raman',)
print(x)
print(type(x))
# Out:
# ('Raman',)
# <class 'tuple'>

# %% [markdown]
# **Indexing Slicing and Negative Indexing**

# %%
x = (1,2,3,4,5)
print(x[3])
# Out:
# 4

# %%
x = (1,2,3,4,5)
print(x[1:3])
# Out:
# (2, 3)

# %%
x = (1,2,3,4,5)
print(x[1:4:2])
# Out:
# (2, 4)

# %%
x = (1,2,3,4,5)
print(x[-3])
# Out:
# 3

# %%
x = (1,2,3,4,5)
print(x[-4:-1])
# Out:
# (2, 3, 4)

# %%
x = (1,2,3,4,5)
if 2 in x:
    print("Two")
else:
    print('No')
# Out:
# Two

# %%
x = (1,2,3,4,5)
if 20 in x:
    print("Two")
else:
    print('No')
# Out:
# No

# %% [markdown]
# # Tuple Operations

# %%
**Add Items**

# %%
 numbers = (1,2,3,4,5,6)
nums = list(numbers)
nums[1] =20

numbers = tuple(nums)
print(numbers)
# Out:
# (1, 20, 3, 4, 5, 6)

# %%
nametuple = ("Bill", "Steve", "Tim")
namelist = list(nametuple)
namelist.insert(2, "Tom")
nametuple = tuple(namelist)
print(nametuple)
# Out:
# ('Bill', 'Steve', 'Tom', 'Tim')

# %% [markdown]
# **Change/Update Item**

# %%
nametuple = ("Bill", "Steve", "Tim")
namelist = list(nametuple)
namelist[2] =  "Tom"
nametuple = tuple(namelist)
print(nametuple)
# Out:
# ('Bill', 'Steve', 'Tom')

# %% [markdown]
# **Remove Items**

# %%
nametuple = ("Bill", "Steve", "Tim")
namelist = list(nametuple)
namelist.remove("Steve")
nametuple = tuple(namelist)
print(nametuple)
# Out:
# ('Bill', 'Tim')

# %% [markdown]
# **Join Tuple**

# %%
numbers = (1,2,3)
numbers2 = (4,5,6)
numbers = numbers + numbers2
print(numbers)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
numbers = (1,2,3)
numbers2 = (4,5,6)
print(id(numbers))
nums.append(4)
numbers = tuple(nums)
print(id(numbers))
print(numbers)
# Out:
# 2308663265984
# 2308662904672
# (1, 20, 3, 4, 5, 6, 4)

# %%
numbers = (1,2,3)
numbers2 = (4,5,6)
print(id(numbers))
numbers = numbers + numbers2
print(id(numbers))
print(numbers)
# Out:
# 2308663266048
# 2308662905344
# (1, 2, 3, 4, 5, 6)

# %%
nametuple = ("Bill", "Steve", "Tim")
newnames = ("Tom", "Sam")
nametuple = nametuple + newnames
print(nametuple)
# Out:
# ('Bill', 'Steve', 'Tim', 'Tom', 'Sam')

# %% [markdown]
# **Delete a Tuple**

# %%
nametuple = ("Bill", "Steve", "Tim")
del nametuple
print(nametuple)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 nametuple = ("Bill", "Steve", "Tim")
#       2 del nametuple
# ----> 3 print(nametuple)
#
# NameError: name 'nametuple' is not defined

# %%
nametuple = ("Bill", "Steve", "Tim")
newnames = ("Tom", "Sam")
nametuple = nametuple + newnames
print(nametuple)
# Out:
# ('Bill', 'Steve', 'Tim', 'Tom', 'Sam')

# %%
nametuple = ("Bill", "Steve", "Tim")
del nametuple
print(nametuple)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[153], line 3
#       1 nametuple = ("Bill", "Steve", "Tim")
#       2 del nametuple
# ----> 3 print(nametuple)
#
# NameError: name 'nametuple' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 numbers = (1,2,3)
#       2 del numbers
# ----> 3 print(numbers)
#
# NameError: name 'numbers' is not defined

# %%
# pritic 
numbers = (1,2,3,4,5,6)
nums = list(numbers)
nums.append(7)
numbers = tuple(nums)
print(numbers)
# Out:
# (1, 2, 3, 4, 5, 6, 7)

# %% [markdown]
# # tuple methods

# %% [markdown]
# **count() method**

# %%
numbers = (1,2,4,4,4,4,4,4,44,3)
print(numbers.count(4))
print(numbers.count(8))
# Out:
# 6
# 0

# %% [markdown]
#  **index() method**

# %%
emp_details = ('Tim','Smith','UK',2,True,'UK')
print(emp_details.index('UK'))
print(emp_details.index('UK',3))
# Out:
# 2
# 5

# %%
emp_details = ('Tim','Smith','UK',2,True,'UK')
print(emp_details.index('UK'))       # → 2
print(emp_details.index('UK', 4))    # → 5
# Out:
# 2
# 5

# %%
numbers = (1,2,4,4,4,4,4,4,44,3)
print(numbers.index(4))
print(numbers.index(3))
# Out:
# 2
# 9

# %%
numbers = (1,2,4,4,4,4,4,4,44,3)
print(numbers.index(3,4))
# Out:
# 9

# %% [markdown]
# # Tuple Indexing

# %%
emp_details = ('Brad','Lee','Sales',380,250000,True)
print(emp_details[0])
print(emp_details[4])
# Out:
# Brad
# 250000

# %% [markdown]
# # Tuple Slicing

# %%
# Only using start to end.


emp_details = ('Brad','Lee','Sales',380,250000,True,'New York','USA','Developer','Python')
print(emp_details[0:])
# Out:
# ('Brad', 'Lee', 'Sales', 380, 250000, True, 'New York', 'USA', 'Developer', 'Python')

# %%
#Start with 3 to end.
print(emp_details[3:])
# Out:
# (380, 250000, True, 'New York', 'USA', 'Developer', 'Python')

# %%
#Go up to 3. Note: Item at position 3 will not be included.
print(emp_details[:3])
# Out:
# ('Brad', 'Lee', 'Sales')

# %%
#Include all jumping a character.

print(emp_details[::2])
# Out:
# ('Brad', 'Sales', 250000, 'New York', 'Developer')

# %%
#Start at 2 up to 8.
print(emp_details[2:8])
# Out:
# ('Sales', 380, 250000, True, 'New York', 'USA')

# %%
#Start with 1 up to 8 with jump of 3.

print(emp_details[1:8:3])
# Out:
# ('Lee', 250000, 'USA')

# %% [markdown]
# # Negative Indexing

# %%
# Item at -2 position.
emp_details = ('Brad','Lee','Sales',380,250000,True,'New York','USA','Developer','Python')
print(emp_details[-2])
# Out:
# Developer

# %%
print(emp_details[-2:-6])
# Out:
# ()

# %%
#Traversing from -2 uptill -6 with jump of -1.


print(emp_details[-2:-6:-1])
# Out:
# ('Developer', 'USA', 'New York', True)

# %%
# Traversing from -5 to -2 with a positive jump i.e. default 1.

print(emp_details[-5:-2])
# Out:
# (True, 'New York', 'USA')

# %%
#We can use this approach to reverse the tuple.
print(emp_details[::-1])
# Out:
# ('Python', 'Developer', 'USA', 'New York', True, 250000, 380, 'Sales', 'Lee', 'Brad')

# %%
# Check if an item exists in Tuple
emp_details = ('Brad','Lee','Sales',380,250000,True)
if ("Brad" in emp_details):
    print("Welcome, Brad!")
    #As Steve is not present, so nothing gets printed.
emp_details = ('Brad','Lee','Sales',380,250000,True)
if ("Steve" in emp_details):
    print("Welcome, Steve!")
# Out:
# Welcome, Brad!

# %%
#Index out of range error
emp_details = ['Brad','Lee']
print(emp_details[2])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[97], line 3
#       1 #Index out of range error
#       2 emp_details = ['Brad','Lee']
# ----> 3 print(emp_details[2])
#
# IndexError: list index out of range

# %% [markdown]
# # tuple packing and unpacking

# %%
numbers = (1,2,3)
one,two,three = numbers
print(one,two,three)
# Out:
# 1 2 3
