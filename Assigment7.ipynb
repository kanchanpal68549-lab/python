# %% [markdown]
# ## (a) Hollow Diamond

# %%
n = 5

for i in range(n):
    print(" "*(n-i-1), end="")
    print("*", end="")
    if i > 0:
        print(" "*(2*i-1), end="")
        print("*", end="")
    print()

for i in range(n-2, -1, -1):
    print(" "*(n-i-1), end="")
    print("*", end="")
    if i > 0:
        print(" "*(2*i-1), end="")
        print("*", end="")
    print()
# Out:
#     *
#    * *
#   *   *
#  *     *
# *       *
#  *     *
#   *   *
#    * *
#     *

# %% [markdown]
# ## (b) Arrow Pattern

# %%
n = 5

for i in range(1, n+1):
    print("* " * i)

for i in range(n-1, 0, -1):
    print("* " * i)
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %% [markdown]
# ## (c) Number Triangle

# %%
n = 5

for i in range(1, n+1):
    for j in range(1, i+1):
        if j == 1 or j == i or i == n:
            print(j, end=" ")
        else:
            print(" ", end=" ")
    print()
# Out:
# 1
# 1 2
# 1   3
# 1     4
# 1 2 3 4 5

# %% [markdown]
# ## (d) Number Pyramid

# %%
n = 5

for i in range(1, n+1):

    print(" "*(n-i), end="")

    for j in range(i, 2*i):
        print(j, end=" ")

    for j in range(2*i-2, i-1, -1):
        print(j, end=" ")

    print()
# Out:
#     1
#    2 3 2
#   3 4 5 4 3
#  4 5 6 7 6 5 4
# 5 6 7 8 9 8 7 6 5

# %% [markdown]
# ## (e) Hollow Number Triangle

# %%
n = 5

for i in range(1, n+1):

    print(" "*(n-i), end="")

    for j in range(1, i+1):

        if j == 1 or j == i or i == n:
            print(j, end=" ")
        else:
            print("  ", end="")

    print()
# Out:
#     1
#    1 2
#   1   3
#  1     4
# 1 2 3 4 5

# %% [markdown]
# ## (f) Z Pattern Using Numbers

# %%
n = 5

for i in range(1, n+1):
    print(i, end=" ")
print()

for i in range(n, 1, -1):
    print(" "*(2*(n-i)), i)
# Out:
# 1 2 3 4 5
#  5
#    4
#      3
#        2
