# %% [markdown]
# # INPUT & OUTPUT

# %%
input("please enter age ")
age = input("please enter age")
print(age)
# Out:
# please enter age  12
# please enter age 12
# 12

# %%
age = input()
print("Age =",age)
# Out:
#  12
# Age = 12

# %%
x= input("please enter frist num ")
y = input("please enter second num ")  #type casted
print(int(x)+int(y))
# Out:
# please enter frist num  3
# please enter second num  2
# 5

# %%
x= int(input("please enter frist num "))
y = int(input("please enter second num "))
print(x+y)
# Out:
# please enter frist num  4
# please enter second num  6
# 10

# %%
x= float(input("please enter frist num "))
y = float(input("please enter second num "))
print(x+y)
# Out:
# please enter frist num  3.2
# please enter second num  3.0
# 6.2

# %%
x= float(input("please enter frist num "))
y = float(input("please enter second num "))

print(x+y)
# Out:
# please enter frist num  abc
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 x= float(input("please enter frist num "))
#       2 y = float(input("please enter second num "))
#       3 print(x+y)
#
# ValueError: could not convert string to float: 'abc'

# %%
#print("Hello" + input("please enter name "))  #nested input
print("Hello" ,  input("please enter name "))  #nested input
# Out:
# please enter name  kannu
# Hello kannu

# %%
print("Hello" , 3,  input("please enter name "))  #nested input
# Out:
# please enter name  kannu
# Hello 3 kannu

# %% [markdown]
# ## PRINT AND INPUT EXERCISE

# %%
where is Tim's Notebook
print('what to print')
serve said "you are right"
Tim's notebook is on the desk
what to print
server said "you are right"
# Out:
#   Cell In[55], line 1
#     where is Tim's Notebook
#                 ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
tim = {
    'notebook': 'on the desk'
}
print(f"Tim's notebook is {tim['notebook']}")
print('what to print')
print('server said "you are right"')
# Out:
# Tim's notebook is on the desk
# what to print
# server said "you are right"

# %%
print("Where is Tim's Notebook")
print('what to print')
print('server said "you are right"')
# Out:
# Where is Tim's Notebook
# what to print
# server said "you are right"

# %%
print("Where is Tim's Notebook",'what to print','server said "you are right"')
# Out:
# Where is Tim's Notebook what to print server said "you are right"

# %%
print("Where is Tim's Notebook"'what to print''server said "you are right"',sep="/")
# Out:
# Where is Tim's Notebookwhat to printserver said "you are right"

# %%
print("Where is Tim's Notebook","\nprint('what to print')","\n'server said \"you are right\"'")
# Out:
# Where is Tim's Notebook
# print('what to print')
# 'server said "you are right"'

# %%
print("Where is Tim's Notebook"'what to print','server said ,"you are right"',sep="\n")

# %%
a = (input("enter the first num"))
b = (input("enter the second num"))
print(a+b)
# Out:
# enter the first num 10
# enter the seconde num 10
# 1010

# %%
a = (input("enter the first num"))
b = (input("enter the second num"))
print(int(a)+int(b))
# Out:
# enter the first num 10
# enter the seconde num 10
# 20

# %%
print("sum=",int(input("enter the first num: ")) + int(input("enter the second num: ")))
# Out:
# enter the first num:  45
# enter the second num:  45
# sum= 90
