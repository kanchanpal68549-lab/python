# %%
# This is the code to 
# add and b and divide the sum
a = 5
b = 10
#adding a and b
sum = a + b
sum = sum/10
print(sum)
# Out:
# 1.5

# %%
a = 5
b = 10
/
#adding a and b
sum = a + b
sum = sum/10
print(sum)
# Out:
#   Cell In[2], line 3
#     /
#     ^
# SyntaxError: invalid syntax

# %%
""" This is the cvode to 
 add and b and divide the sum
"""
a = 5
b = 10

sum = a + b
#Doc_v4 Page 4
#sum = sum/10
# TO DO: Remove this print
print(sum)
# Out:
# 15

# %%
# SYNTAQX

# %%
#" "''

# %%
print(20)
# Out:
# 20

# %%
print(20)
  print(20)   #without indentation 
              #same indentation use kare
print(20)
# Out:
#   Cell In[7], line 2
#     print(20)   #without indentation
#     ^
# IndentationError: unexpected indent

# %%
print(20)   # SAME INDENTATION follow
print(20)   
print(20)
# Out:
# 20
# 20
# 20

# %%
print(20);    # IT'S NOT REQUEIRMENTATION 
print(20)   
print(20)
# Out:
# 20
# 20
# 20

# %%
a = 5
a1    =          50  # no problem 
print(a)
print(a1)
print(20)   
print(20)
# Out:
# 5
# 50
# 20
# 20

# %%
text =""
