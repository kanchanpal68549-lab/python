# %%
x =20
y = 40
z = (x+y)
print(z)
# Out:
# 60

# %%
x = input ("Enter the first number")
y = input ("Enter the second number")
z = (x+y)

r = ("x"+"y")
print(z)
print(r)
# Out:
# Enter the first number 10
# Enter the second number 20
# 1020
# xy

# %%
x = input ("Enter the first number")
y = input ("Enter the second number")
z = 30
print("Sum is",z)
print("sum",x,"and",y,"is=",z)
# Out:
# Enter the first number 10
# Enter the second number 20
# Sum is 30
# sum 10 and 20 is= 30

# %%
x = input ("Enter the first number")
y = input ("Enter the second number")
z = 30
print("Sum is",z)
print(x,"+",y,"=",z)
# Out:
# Enter the first number 10
# Enter the second number 20
# Sum is 30
# 10 + 20 = 30

# %%
# find the amount to be paid based on discount

# %%
amount = float(input("enter the amount:"))
discount = float(input("enter discount:"))
final = amount - discount
final_price = amount - amount * discount/100
print(final)
print("please pay:",final_price)
# Out:
# enter the amount: 10000
# enter discount: 20
# 9980.0
# please pay: 8000.0

# %%
# write a program to find sum 2 digit  num

# %%
num = int(input("Enter the 2 digit num"))
q = num // 10
r = num % 10
sum = q + r
print(r*10+4)
# Out:
# Enter the 2 digit num 45
# 54
